# %%
import json

with open('sample1.json', 'r') as file:
    data = json.load(file)

print(data)
# Out:
# {'users': [{'id': 1, 'name': 'Alice', 'email': 'alice@example.com', 'dob': '1990-05-10', 'address': {'street': '123 Elm St', 'city': 'Wonderland', 'postal_code': '12345'}}, {'id': 2, 'name': 'Bob', 'email': 'bob@example.com', 'dob': '1985-08-20', 'address': {'street': '456 Maple Ave', 'city': 'Fictionville', 'postal_code': '67890'}}, {'id': 3, 'name': 'Charlie', 'email': 'charlie@example.com', 'dob': '1992-11-15', 'address': {'street': '789 Oak Rd', 'city': 'Storytown', 'postal_code': '13579'}}], 'orders': [{'order_id': 'ORD001', 'user_id': 1, 'order_date': '2025-01-10', 'total': 250.5, 'items': [{'product_id': 'P001', 'name': 'Laptop', 'price': 200, 'quantity': 1}, {'product_id': 'P003', 'name': 'Mouse', 'price': 50.5, 'quantity': 1}]}, {'order_id': 'ORD002', 'user_id': 2, 'order_date': '2025-01-12', 'total': 300, 'items': [{'product_id': 'P002', 'name': 'Smartphone', 'price': 300, 'quantity': 1}]}, {'order_id': 'ORD003', 'user_id': 3, 'order_date': '2025-01-15', 'total': 150, 'items': [{'product_id': 'P004', 'name': 'Keyboard', 'price': 150, 'quantity': 1}]}], 'products': [{'product_id': 'P001', 'name': 'Laptop', 'category': 'Electronics', 'price': 200, 'stock': 50}, {'product_id': 'P002', 'name': 'Smartphone', 'category': 'Electronics', 'price': 300, 'stock': 30}, {'product_id': 'P003', 'name': 'Mouse', 'category': 'Accessories', 'price': 50.5, 'stock': 100}, {'product_id': 'P004', 'name': 'Keyboard', 'category': 'Accessories', 'price': 150, 'stock': 75}]}

# %%
import json

with open('sample1.json', 'r') as file:
    data = json.load(file)

print(json.dumps(data, indent=2))
# Out:
# {
#   "users": [
#     {
#       "id": 1,
#       "name": "Alice",
#       "email": "alice@example.com",
#       "dob": "1990-05-10",
#       "address": {
#         "street": "123 Elm St",
#         "city": "Wonderland",
#         "postal_code": "12345"
#       }
#     },
#     {
#       "id": 2,
#       "name": "Bob",
#       "email": "bob@example.com",
#       "dob": "1985-08-20",
#       "address": {
#         "street": "456 Maple Ave",
#         "city": "Fictionville",
#         "postal_code": "67890"
#       }
#     },
#     {
#       "id": 3,
#       "name": "Charlie",
#       "email": "charlie@example.com",
#       "dob": "1992-11-15",
#       "address": {
#         "street": "789 Oak Rd",
#         "city": "Storytown",
#         "postal_code": "13579"
#       }
#     }
#   ],
#   "orders": [
#     {
#       "order_id": "ORD001",
#       "user_id": 1,
#       "order_date": "2025-01-10",
#       "total": 250.5,
#       "items": [
#         {
#           "product_id": "P001",
#           "name": "Laptop",
#           "price": 200,
#           "quantity": 1
#         },
#         {
#           "product_id": "P003",
#           "name": "Mouse",
#           "price": 50.5,
#           "quantity": 1
#         }
#       ]
#     },
#     {
#       "order_id": "ORD002",
#       "user_id": 2,
#       "order_date": "2025-01-12",
#       "total": 300,
#       "items": [
#         {
#           "product_id": "P002",
#           "name": "Smartphone",
#           "price": 300,
#           "quantity": 1
#         }
#       ]
#     },
#     {
#       "order_id": "ORD003",
#       "user_id": 3,
#       "order_date": "2025-01-15",
#       "total": 150,
#       "items": [
#         {
#           "product_id": "P004",
#           "name": "Keyboard",
#           "price": 150,
#           "quantity": 1
#         }
#       ]
#     }
#   ],
#   "products": [
#     {
#       "product_id": "P001",
#       "name": "Laptop",
#       "category": "Electronics",
#       "price": 200,
#       "stock": 50
#     },
#     {
#       "product_id": "P002",
#       "name": "Smartphone",
#       "category": "Electronics",
#       "price": 300,
#       "stock": 30
#     },
#     {
#       "product_id": "P003",
#       "name": "Mouse",
#       "category": "Accessories",
#       "price": 50.5,
#       "stock": 100
#     },
#     {
#       "product_id": "P004",
#       "name": "Keyboard",
#       "category": "Accessories",
#       "price": 150,
#       "stock": 75
#     }
#   ]
# }

# %%
for user in data['users']:
    print(f"User ID: {user['id']}, Name: {user['name']}, Email: {user['email']}")

for order in data['orders']:
    print(f"Order ID: {order['order_id']}, Total: {order['total']}")

for product in data['products']:
    print(f"Product Name: {product['name']}, Price: {product['price']}")
# Out:
# User ID: 1, Name: Alice, Email: alice@example.com
# User ID: 2, Name: Bob, Email: bob@example.com
# User ID: 3, Name: Charlie, Email: charlie@example.com
# Order ID: ORD001, Total: 250.5
# Order ID: ORD002, Total: 300
# Order ID: ORD003, Total: 150
# Product Name: Laptop, Price: 200
# Product Name: Smartphone, Price: 300
# Product Name: Mouse, Price: 50.5
# Product Name: Keyboard, Price: 150

# %%
import json

fields = ['Name', 'Branch', 'Year', 'CGPA']

rows = [['A', 'CE', '1', '8.6'],
        ['B', 'IT', '3', '7.8'],
        ['C', 'ME', '2', '5.1'],
        ['X', 'CE', '4', '9.0'],
        ['Y', 'IT', '1', '7.1'],
        ['Z', 'ME', '4', '8.3']]

filename = "Student_records.json"

data = [dict(zip(fields, row)) for row in rows]

with open(filename, 'w') as jsonfile:
    json.dump(data, jsonfile, indent=4)
